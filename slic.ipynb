# %%
import rasterio as rio
from rasterio.plot import show
from matplotlib import pyplot
from skimage.segmentation import slic, mark_boundaries

# %%
imagem = rio.open(r'C:\Users\10333076966\Documents\Mauricio_MESTRADO\PANSHAPERNING\PANSHARPENED_NORMAL.tif','r')

# %%
matrix = imagem.read()

# %%
matrix.shape
# Out:
# (4, 9103, 16248)

# %%
show((imagem,1), cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
imagem.crs
# Out:
# CRS.from_epsg(32722)

# %%
segmentation = slic(matrix, n_segments=500, sigma = 4)

# %%
pyplot.imshow(segmentation, cmap='pink')
pyplot.show()

# %%
    with rio.open(
        'slic.tif',
    'w',
    driver='GTiff',
    height=matrix.shape[0],
    width=matrix.shape[1],
    count=matrix.shape[2],
    dtype=matrix.dtype,
    crs=imagem.crs,
    transform=imagem.transform,
) as dst:
    dst.write(teste, 1)
